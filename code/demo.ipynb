# %%
import pandas as pd

# %%
pd.set_option("display.max_columns",None)
pd.set_option("display.max_rows",None)

# %%
data=pd.read_csv("new_train_sample.csv")

# %%
sample_data=data.copy()

# %%
sample_data.shape
# Out:
# (4758418, 46)

# %%
sample_data.head()
# Out:
#    Unnamed: 0             Id  OrgId  IncidentId  AlertId  \
# 0     5172780  1709396985476     26       18583   687462
# 1     8470561   927712939180     33        5065     3990
# 2     5897583  1090921697002    201      150787   807590
# 3     3288552  1434519079555    204      108287    28575
# 4     4060961  1005022347708     54      528202  1458226
#
#                   Timestamp  DetectorId  AlertTitle            Category  \
# 0  2024-06-06T05:56:47.000Z          31         813             Malware
# 1  2024-06-03T10:45:09.000Z          38          25              Impact
# 2  2024-06-13T03:36:40.000Z         419         444           Execution
# 3  2024-06-08T16:54:57.000Z          44        1233  SuspiciousActivity
# 4  2024-06-09T02:48:01.000Z         102       58829        Exfiltration
#
#                                      MitreTechniques   IncidentGrade  \
# 0                                                NaN  BenignPositive
# ...

# %%
null_check=sample_data.isnull().mean()*100

# %%
null_check
# Out:
# Unnamed: 0             0.000000
# Id                     0.000000
# OrgId                  0.000000
# IncidentId             0.000000
# AlertId                0.000000
# Timestamp              0.000000
# DetectorId             0.000000
# AlertTitle             0.000000
# Category               0.000000
# MitreTechniques       57.437913
# IncidentGrade          0.541672
# ActionGrouped         99.407093
# ActionGranular        99.407093
# EntityType             0.000000
# EvidenceRole           0.000000
# DeviceId               0.000000
# Sha256                 0.000000
# IpAddress              0.000000
# Url                    0.000000
# AccountSid             0.000000
# AccountUpn             0.000000
# AccountObjectId        0.000000
# AccountName            0.000000
# DeviceName             0.000000
# NetworkMessageId       0.000000
# EmailClusterId        98.987542
# RegistryKey            0.000000
# RegistryValueName      0.000000
# RegistryValueData      0.000000
# ...

# %%
not_null_values=null_check[null_check>50].index

# %%
not_null_values
# Out:
# Index(['MitreTechniques', 'ActionGrouped', 'ActionGranular', 'EmailClusterId',
#        'ThreatFamily', 'ResourceType', 'Roles', 'AntispamDirection',
#        'SuspicionLevel', 'LastVerdict'],
#       dtype='object')

# %%
more_than_50=['MitreTechniques', 'ActionGrouped', 'ActionGranular', 'EmailClusterId',
       'ThreatFamily', 'ResourceType', 'Roles', 'AntispamDirection',
       'SuspicionLevel', 'LastVerdict']

# %%
sample_data.drop(more_than_50,axis=1,inplace=True)

# %%
sample_data.isnull().mean()*100
# Out:
# Unnamed: 0            0.000000
# Id                    0.000000
# OrgId                 0.000000
# IncidentId            0.000000
# AlertId               0.000000
# Timestamp             0.000000
# DetectorId            0.000000
# AlertTitle            0.000000
# Category              0.000000
# IncidentGrade         0.541672
# EntityType            0.000000
# EvidenceRole          0.000000
# DeviceId              0.000000
# Sha256                0.000000
# IpAddress             0.000000
# Url                   0.000000
# AccountSid            0.000000
# AccountUpn            0.000000
# AccountObjectId       0.000000
# AccountName           0.000000
# DeviceName            0.000000
# NetworkMessageId      0.000000
# RegistryKey           0.000000
# RegistryValueName     0.000000
# RegistryValueData     0.000000
# ApplicationId         0.000000
# ApplicationName       0.000000
# OAuthApplicationId    0.000000
# FileName              0.000000
# FolderPath            0.000000
# ...

# %%
sample_data["IncidentGrade"].value_counts()
# Out:
# IncidentGrade
# BenignPositive    2054774
# TruePositive      1662087
# FalsePositive     1015782
# Name: count, dtype: int64

# %%
drop_nan=sample_data["IncidentGrade"].isnull().sum()

# %%
sample_data.dropna(subset=["IncidentGrade"],inplace=True)

# %%
drop_nan
# Out:
# 25775

# %%
int_values=sample_data.select_dtypes(include="int")

# %%
int_values.head()
# Out:
#    Unnamed: 0             Id  OrgId  IncidentId  AlertId  DetectorId  \
# 0     5172780  1709396985476     26       18583   687462          31
# 1     8470561   927712939180     33        5065     3990          38
# 2     5897583  1090921697002    201      150787   807590         419
# 3     3288552  1434519079555    204      108287    28575          44
# 4     4060961  1005022347708     54      528202  1458226         102
#
#    AlertTitle  DeviceId  Sha256  IpAddress     Url  AccountSid  AccountUpn  \
# 0         813     98799    1296     360606  160396      441377      673934
# 1          25     98799  138268     360606  160396      441377      673934
# 2         444     98799  138268     360606  160396      441377      673934
# 3        1233     98799  138268     360606  160396      441377      673934
# 4       58829     98799  138268     360606  160396      441377      673934
#
#    AccountObjectId  AccountName  DeviceName  NetworkMessageId  RegistryKey  \
# ...

# %%
["FolderPath","OSFamily","DeviceName"]
# Out:
# ['FolderPath', 'OSFamily', 'DeviceName']

# %%
sample_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 4732643 entries, 0 to 4758417
# Data columns (total 36 columns):
#  #   Column              Dtype
# ---  ------              -----
#  0   Unnamed: 0          int64
#  1   Id                  int64
#  2   OrgId               int64
#  3   IncidentId          int64
#  4   AlertId             int64
#  5   Timestamp           object
#  6   DetectorId          int64
#  7   AlertTitle          int64
#  8   Category            object
#  9   IncidentGrade       object
#  10  EntityType          object
#  11  EvidenceRole        object
#  12  DeviceId            int64
#  13  Sha256              int64
#  14  IpAddress           int64
#  15  Url                 int64
#  16  AccountSid          int64
#  17  AccountUpn          int64
#  18  AccountObjectId     int64
#  19  AccountName         int64
#  20  DeviceName          int64
#  21  NetworkMessageId    int64
#  22  RegistryKey         int64
#  23  RegistryValueName   int64
# ...

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# %%
data_corr=int_values.corr()
plt.figure(figsize=(30,30))
sns.heatmap(data_corr,annot=True)
# Out:
# <Axes: >

# %%
corr_drop=["AccountSid","AccountUpn","AccountObjectId","RegistryValueData","ApplicationName","FileName","OSVersion","State","City"]

# %%
sample_data.drop(corr_drop,axis=1,inplace=True)

# %%
corr_drop2=["FolderPath","OSFamily","DeviceName"]

# %%
sample_data.drop(corr_drop2,axis=1,inplace=True)

# %%
sample_data.duplicated().value_counts()
# Out:
# False    4732643
# Name: count, dtype: int64

# %%
sample_data.head()
# Out:
#    Unnamed: 0             Id  OrgId  IncidentId  AlertId  \
# 0     5172780  1709396985476     26       18583   687462
# 1     8470561   927712939180     33        5065     3990
# 2     5897583  1090921697002    201      150787   807590
# 3     3288552  1434519079555    204      108287    28575
# 4     4060961  1005022347708     54      528202  1458226
#
#                   Timestamp  DetectorId  AlertTitle            Category  \
# 0  2024-06-06T05:56:47.000Z          31         813             Malware
# 1  2024-06-03T10:45:09.000Z          38          25              Impact
# 2  2024-06-13T03:36:40.000Z         419         444           Execution
# 3  2024-06-08T16:54:57.000Z          44        1233  SuspiciousActivity
# 4  2024-06-09T02:48:01.000Z         102       58829        Exfiltration
#
#     IncidentGrade EntityType EvidenceRole  DeviceId  Sha256  IpAddress  \
# 0  BenignPositive       File      Related     98799    1296     360606
# ...

# %%
sample_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 4732643 entries, 0 to 4758417
# Data columns (total 24 columns):
#  #   Column              Dtype
# ---  ------              -----
#  0   Unnamed: 0          int64
#  1   Id                  int64
#  2   OrgId               int64
#  3   IncidentId          int64
#  4   AlertId             int64
#  5   Timestamp           object
#  6   DetectorId          int64
#  7   AlertTitle          int64
#  8   Category            object
#  9   IncidentGrade       object
#  10  EntityType          object
#  11  EvidenceRole        object
#  12  DeviceId            int64
#  13  Sha256              int64
#  14  IpAddress           int64
#  15  Url                 int64
#  16  AccountName         int64
#  17  NetworkMessageId    int64
#  18  RegistryKey         int64
#  19  RegistryValueName   int64
#  20  ApplicationId       int64
#  21  OAuthApplicationId  int64
#  22  ResourceIdName      int64
#  23  CountryCode         int64
# ...

# %%
sample_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 4732643 entries, 0 to 4758417
# Data columns (total 24 columns):
#  #   Column              Dtype
# ---  ------              -----
#  0   Unnamed: 0          int64
#  1   Id                  int64
#  2   OrgId               int64
#  3   IncidentId          int64
#  4   AlertId             int64
#  5   Timestamp           object
#  6   DetectorId          int64
#  7   AlertTitle          int64
#  8   Category            object
#  9   IncidentGrade       object
#  10  EntityType          object
#  11  EvidenceRole        object
#  12  DeviceId            int64
#  13  Sha256              int64
#  14  IpAddress           int64
#  15  Url                 int64
#  16  AccountName         int64
#  17  NetworkMessageId    int64
#  18  RegistryKey         int64
#  19  RegistryValueName   int64
#  20  ApplicationId       int64
#  21  OAuthApplicationId  int64
#  22  ResourceIdName      int64
#  23  CountryCode         int64
# ...

# %%
sample_data.to_csv("cleaning_data1.csv",index=False)
